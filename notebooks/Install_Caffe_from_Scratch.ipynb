# %% [markdown]
# <a href="https://colab.research.google.com/github/RahulSinghalChicago/fb-mle-capstone/blob/main/notebooks/Install_Caffe_from_Scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%shell
# sudo apt-get update && sudo apt-get upgrade && sudo apt-get dist-upgrade && sudo apt-get autoremove
#
# sudo apt-get -y install libopenblas-dev
#
# echo 'deb http://archive.ubuntu.com/ubuntu trusty main restricted universe multiverse' >>/tmp/multiverse.list
# sudo cp /tmp/multiverse.list /etc/apt/sources.list.d/
# rm /tmp/multiverse.list
# Out:
# Get:1 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:4 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:5 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:8 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:9 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:11 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,810 kB]
# Ign:12 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:13 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [696 B]
# Hit:14 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:15 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:16 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [926 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [665 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,213 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,835 kB]
# Get:20 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [69.5 kB]
# Get:21 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [45.3 kB]
# Get:23 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [753 kB]
# Get:24 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [632 kB]
# Get:25 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,398 kB]
# Get:26 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,434 kB]
# Fetched 14.1 MB in 2s (6,403 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Calculating upgrade... Done
# The following packages have been kept back:
#   cuda-drivers libcudnn8 libcudnn8-dev libnccl-dev libnccl2
#   linux-headers-generic
# The following packages will be upgraded:
#   base-files binutils binutils-common binutils-x86-64-linux-gnu
#   distro-info-data gnupg2 gzip libaudit-common libaudit1 libbinutils libc-bin
#   libcaca0 libcublas-dev libcublas10 libcudnn7 libcudnn7-dev libgnutls30
#   libhogweed4 libldap-2.4-2 libldap-common liblz4-1 libmysqlclient-dev
#   libmysqlclient20 libnettle6 libp11-kit0 libpam-modules libpam-modules-bin
#   libpam-runtime libpam0g libsasl2-2 libsasl2-modules-db libseccomp2
#   libxnvctrl0 libzstd1 linux-libc-dev nvidia-modprobe nvidia-settings openssl
#   r-cran-cpp11 r-cran-data.table r-cran-desc r-cran-diffobj r-cran-digest
#   r-cran-hms r-cran-knitr r-cran-lifecycle r-cran-lubridate r-cran-mgcv
#   r-cran-mime r-cran-pillar r-cran-pkgload r-cran-rcmdcheck r-cran-readr
#   r-cran-remotes r-cran-rlang r-cran-rvest r-cran-stringi r-cran-systemfonts
#   r-cran-testthat r-cran-tibble r-cran-tidyr r-cran-tinytex r-cran-usethis
#   r-cran-xfun tar ubuntu-keyring
# 66 upgraded, 0 newly installed, 0 to remove and 6 not upgraded.
# Need to get 468 MB of archives.
# After this operation, 70.2 MB of additional disk space will be used.
# Get:1 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-cpp11 all 0.4.0-1cran1.1804.0 [215 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 base-files amd64 10.1ubuntu2.11 [60.4 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gzip amd64 1.6-5ubuntu1.1 [89.8 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 tar amd64 1.29b-2ubuntu0.2 [234 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libc-bin amd64 2.27-3ubuntu1.4 [643 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libaudit-common all 1:2.8.2-1ubuntu1.1 [4,068 B]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libaudit1 amd64 1:2.8.2-1ubuntu1.1 [38.7 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpam0g amd64 1.1.8-3.6ubuntu2.18.04.3 [55.0 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpam-modules-bin amd64 1.1.8-3.6ubuntu2.18.04.3 [40.3 kB]
# Get:10 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-data.table amd64 1.14.2-1cran1.1804.0 [1,825 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpam-modules amd64 1.1.8-3.6ubuntu2.18.04.3 [252 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 liblz4-1 amd64 0.0~r131-2ubuntu3.1 [48.5 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpam-runtime all 1.1.8-3.6ubuntu2.18.04.3 [37.1 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libzstd1 amd64 1.3.3+dfsg-2ubuntu1.2 [189 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libnettle6 amd64 3.4.1-0ubuntu0.18.04.1 [111 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libhogweed4 amd64 3.4.1-0ubuntu0.18.04.1 [140 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libp11-kit0 amd64 0.23.9-2ubuntu0.1 [187 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgnutls30 amd64 3.5.18-1ubuntu1.5 [646 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libseccomp2 amd64 2.5.1-1ubuntu1~18.04.1 [43.1 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 ubuntu-keyring all 2018.09.18.1~18.04.2 [22.3 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 distro-info-data all 0.37ubuntu0.13 [4,656 B]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 openssl amd64 1.1.1-1ubuntu2.1~18.04.13 [614 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 binutils-x86-64-linux-gnu amd64 2.30-21ubuntu1~18.04.7 [1,839 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 binutils-common amd64 2.30-21ubuntu1~18.04.7 [197 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 binutils amd64 2.30-21ubuntu1~18.04.7 [3,388 B]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libbinutils amd64 2.30-21ubuntu1~18.04.7 [489 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcaca0 amd64 0.99.beta19-2ubuntu0.18.04.3 [203 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsasl2-modules-db amd64 2.1.27~101-g0780600+dfsg-3ubuntu2.3 [15.0 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsasl2-2 amd64 2.1.27~101-g0780600+dfsg-3ubuntu2.3 [49.2 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libldap-common all 2.4.45+dfsg-1ubuntu1.10 [15.8 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libldap-2.4-2 amd64 2.4.45+dfsg-1ubuntu1.10 [154 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmysqlclient-dev amd64 5.7.36-0ubuntu0.18.04.1 [1,017 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmysqlclient20 amd64 5.7.36-0ubuntu0.18.04.1 [689 kB]
# Get:34 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ r-cran-mgcv 1.8-38-1.1804.0 [2,971 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 linux-libc-dev amd64 4.15.0-161.169 [985 kB]
# Get:36 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-desc all 1.4.0-1cran1.1804.0 [502 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 gnupg2 all 2.2.4-1ubuntu1.4 [5,292 B]
# Get:38 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-diffobj amd64 0.3.5-1cran1.1804.0 [949 kB]
# Get:39 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-digest amd64 0.6.28-1cran1.1804.0 [190 kB]
# Get:40 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-rlang amd64 0.4.12-1cran1.1804.0 [1,044 kB]
# Get:41 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-lifecycle all 1.0.1-1cran1.1804.0 [96.7 kB]
# Get:42 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcublas10 10.2.3.254-1 [43.1 MB]
# Get:43 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-hms all 1.1.1-1cran1.1804.0 [98.6 kB]
# Get:44 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-xfun amd64 0.27-1cran1.1804.0 [348 kB]
# Get:45 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-knitr all 1.36-1cran1.1804.0 [1,211 kB]
# Get:46 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-lubridate amd64 1.8.0-1cran1.1804.0 [996 kB]
# Get:47 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-mime amd64 0.12-1cran1.1804.0 [34.4 kB]
# Get:48 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-pillar all 1.6.4-1cran1.1804.0 [903 kB]
# Get:49 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-pkgload all 1.2.3-1cran1.1804.0 [153 kB]
# Get:50 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-rcmdcheck all 1.4.0-1cran1.1804.0 [169 kB]
# Get:51 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-tibble amd64 3.1.5-1cran1.1804.0 [700 kB]
# Get:52 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-readr amd64 2.0.2-1cran1.1804.0 [807 kB]
# Get:53 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-remotes all 2.4.1-1cran1.1804.0 [388 kB]
# Get:54 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-rvest all 1.0.2-1cran1.1804.0 [192 kB]
# Get:55 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-stringi amd64 1.7.5-1cran1.1804.0 [805 kB]
# Get:56 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-systemfonts amd64 1.0.3-1cran1.1804.0 [245 kB]
# Get:57 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-testthat amd64 3.1.0-1cran1.1804.0 [1,445 kB]
# Get:58 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-tidyr amd64 1.1.4-1cran1.1804.0 [779 kB]
# Get:59 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-tinytex all 0.34-1cran1.1804.0 [123 kB]
# Get:60 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-usethis all 2.1.0-1cran1.1804.0 [743 kB]
# Get:61 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcublas-dev 10.2.3.254-1 [42.4 MB]
# Get:62 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  libcudnn7-dev 7.6.5.32-1+cuda10.2 [165 MB]
# Get:63 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  libcudnn7 7.6.5.32-1+cuda10.2 [189 MB]
# Get:64 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libxnvctrl0 495.29.05-0ubuntu1 [21.4 kB]
# Get:65 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  nvidia-settings 495.29.05-0ubuntu1 [923 kB]
# Get:66 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  nvidia-modprobe 495.29.05-0ubuntu1 [19.8 kB]
# Fetched 468 MB in 11s (41.5 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 66.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../base-files_10.1ubuntu2.11_amd64.deb ...
# Unpacking base-files (10.1ubuntu2.11) over (10.1ubuntu2.10) ...
# Setting up base-files (10.1ubuntu2.11) ...
# Installing new version of config file /etc/issue ...
# Installing new version of config file /etc/issue.net ...
# Installing new version of config file /etc/lsb-release ...
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../gzip_1.6-5ubuntu1.1_amd64.deb ...
# Unpacking gzip (1.6-5ubuntu1.1) over (1.6-5ubuntu1) ...
# Setting up gzip (1.6-5ubuntu1.1) ...
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../tar_1.29b-2ubuntu0.2_amd64.deb ...
# Unpacking tar (1.29b-2ubuntu0.2) over (1.29b-2ubuntu0.1) ...
# Setting up tar (1.29b-2ubuntu0.2) ...
# update-alternatives: warning: forcing reinstallation of alternative /usr/sbin/rmt-tar because link group rmt is broken
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../libc-bin_2.27-3ubuntu1.4_amd64.deb ...
# Unpacking libc-bin (2.27-3ubuntu1.4) over (2.27-3ubuntu1.3) ...
# Setting up libc-bin (2.27-3ubuntu1.4) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../libaudit-common_1%3a2.8.2-1ubuntu1.1_all.deb ...
# Unpacking libaudit-common (1:2.8.2-1ubuntu1.1) over (1:2.8.2-1ubuntu1) ...
# Setting up libaudit-common (1:2.8.2-1ubuntu1.1) ...
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../libaudit1_1%3a2.8.2-1ubuntu1.1_amd64.deb ...
# Unpacking libaudit1:amd64 (1:2.8.2-1ubuntu1.1) over (1:2.8.2-1ubuntu1) ...
# Setting up libaudit1:amd64 (1:2.8.2-1ubuntu1.1) ...
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../libpam0g_1.1.8-3.6ubuntu2.18.04.3_amd64.deb ...
# Unpacking libpam0g:amd64 (1.1.8-3.6ubuntu2.18.04.3) over (1.1.8-3.6ubuntu2.18.04.2) ...
# Setting up libpam0g:amd64 (1.1.8-3.6ubuntu2.18.04.3) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../libpam-modules-bin_1.1.8-3.6ubuntu2.18.04.3_amd64.deb ...
# Unpacking libpam-modules-bin (1.1.8-3.6ubuntu2.18.04.3) over (1.1.8-3.6ubuntu2.18.04.2) ...
# Setting up libpam-modules-bin (1.1.8-3.6ubuntu2.18.04.3) ...
# (Reading database ... 155049 files and directories currently installed.)
# Preparing to unpack .../libpam-modules_1.1.8-3.6ubuntu2.18.04.3_amd64.deb ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Unpacking libpam-modules:amd64 (1.1.8-3.6ubuntu2.18.04.3) over (1.1.8-3.6ubuntu2.18.04.2) ...
# Setting up libpam-modules:amd64 (1.1.8-3.6ubuntu2.18.04.3) ...
# (Reading database ... 155053 files and directories currently installed.)
# Preparing to unpack .../liblz4-1_0.0~r131-2ubuntu3.1_amd64.deb ...
# Unpacking liblz4-1:amd64 (0.0~r131-2ubuntu3.1) over (0.0~r131-2ubuntu3) ...
# Setting up liblz4-1:amd64 (0.0~r131-2ubuntu3.1) ...
# (Reading database ... 155053 files and directories currently installed.)
# Preparing to unpack .../libpam-runtime_1.1.8-3.6ubuntu2.18.04.3_all.deb ...
# Unpacking libpam-runtime (1.1.8-3.6ubuntu2.18.04.3) over (1.1.8-3.6ubuntu2.18.04.2) ...
# Setting up libpam-runtime (1.1.8-3.6ubuntu2.18.04.3) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# (Reading database ... 155053 files and directories currently installed.)
# Preparing to unpack .../libzstd1_1.3.3+dfsg-2ubuntu1.2_amd64.deb ...
# Unpacking libzstd1:amd64 (1.3.3+dfsg-2ubuntu1.2) over (1.3.3+dfsg-2ubuntu1.1) ...
# Setting up libzstd1:amd64 (1.3.3+dfsg-2ubuntu1.2) ...
# (Reading database ... 155053 files and directories currently installed.)
# Preparing to unpack .../libnettle6_3.4.1-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking libnettle6:amd64 (3.4.1-0ubuntu0.18.04.1) over (3.4-1) ...
# Setting up libnettle6:amd64 (3.4.1-0ubuntu0.18.04.1) ...
# (Reading database ... 155053 files and directories currently installed.)
# Preparing to unpack .../libhogweed4_3.4.1-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking libhogweed4:amd64 (3.4.1-0ubuntu0.18.04.1) over (3.4-1) ...
# Setting up libhogweed4:amd64 (3.4.1-0ubuntu0.18.04.1) ...
# (Reading database ... 155053 files and directories currently installed.)
# Preparing to unpack .../libp11-kit0_0.23.9-2ubuntu0.1_amd64.deb ...
# Unpacking libp11-kit0:amd64 (0.23.9-2ubuntu0.1) over (0.23.9-2) ...
# Setting up libp11-kit0:amd64 (0.23.9-2ubuntu0.1) ...
# (Reading database ... 155053 files and directories currently installed.)
# Preparing to unpack .../libgnutls30_3.5.18-1ubuntu1.5_amd64.deb ...
# Unpacking libgnutls30:amd64 (3.5.18-1ubuntu1.5) over (3.5.18-1ubuntu1.4) ...
# Setting up libgnutls30:amd64 (3.5.18-1ubuntu1.5) ...
# (Reading database ... 155053 files and directories currently installed.)
# Preparing to unpack .../libseccomp2_2.5.1-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking libseccomp2:amd64 (2.5.1-1ubuntu1~18.04.1) over (2.4.3-1ubuntu3.18.04.3) ...
# Setting up libseccomp2:amd64 (2.5.1-1ubuntu1~18.04.1) ...
# (Reading database ... 155053 files and directories currently installed.)
# Preparing to unpack .../ubuntu-keyring_2018.09.18.1~18.04.2_all.deb ...
# Unpacking ubuntu-keyring (2018.09.18.1~18.04.2) over (2018.09.18.1~18.04.0) ...
# Setting up ubuntu-keyring (2018.09.18.1~18.04.2) ...
# (Reading database ... 155053 files and directories currently installed.)
# Preparing to unpack .../00-distro-info-data_0.37ubuntu0.13_all.deb ...
# Unpacking distro-info-data (0.37ubuntu0.13) over (0.37ubuntu0.12) ...
# Preparing to unpack .../01-openssl_1.1.1-1ubuntu2.1~18.04.13_amd64.deb ...
# Unpacking openssl (1.1.1-1ubuntu2.1~18.04.13) over (1.1.1-1ubuntu2.1~18.04.7) ...
# Preparing to unpack .../02-binutils-x86-64-linux-gnu_2.30-21ubuntu1~18.04.7_amd64.deb ...
# Unpacking binutils-x86-64-linux-gnu (2.30-21ubuntu1~18.04.7) over (2.30-21ubuntu1~18.04.4) ...
# Preparing to unpack .../03-binutils-common_2.30-21ubuntu1~18.04.7_amd64.deb ...
# Unpacking binutils-common:amd64 (2.30-21ubuntu1~18.04.7) over (2.30-21ubuntu1~18.04.4) ...
# Preparing to unpack .../04-binutils_2.30-21ubuntu1~18.04.7_amd64.deb ...
# Unpacking binutils (2.30-21ubuntu1~18.04.7) over (2.30-21ubuntu1~18.04.4) ...
# Preparing to unpack .../05-libbinutils_2.30-21ubuntu1~18.04.7_amd64.deb ...
# Unpacking libbinutils:amd64 (2.30-21ubuntu1~18.04.7) over (2.30-21ubuntu1~18.04.4) ...
# Preparing to unpack .../06-libcaca0_0.99.beta19-2ubuntu0.18.04.3_amd64.deb ...
# Unpacking libcaca0:amd64 (0.99.beta19-2ubuntu0.18.04.3) over (0.99.beta19-2ubuntu0.18.04.2) ...
# Preparing to unpack .../07-libcublas10_10.2.3.254-1_amd64.deb ...
# Unpacking libcublas10 (10.2.3.254-1) over (10.2.1.243-1) ...
# Preparing to unpack .../08-libcublas-dev_10.2.3.254-1_amd64.deb ...
# Unpacking libcublas-dev (10.2.3.254-1) over (10.2.1.243-1) ...
# Preparing to unpack .../09-libcudnn7-dev_7.6.5.32-1+cuda10.2_amd64.deb ...
# update-alternatives: removing manually selected alternative - switching libcudnn to auto mode
# update-alternatives: using /usr/include/x86_64-linux-gnu/cudnn_v8.h to provide /usr/include/cudnn.h (libcudnn) in auto mode
# Unpacking libcudnn7-dev (7.6.5.32-1+cuda10.2) over (7.6.5.32-1+cuda10.1) ...
# Preparing to unpack .../10-libcudnn7_7.6.5.32-1+cuda10.2_amd64.deb ...
# Unpacking libcudnn7 (7.6.5.32-1+cuda10.2) over (7.6.5.32-1+cuda10.1) ...
# Preparing to unpack .../11-libsasl2-modules-db_2.1.27~101-g0780600+dfsg-3ubuntu2.3_amd64.deb ...
# Unpacking libsasl2-modules-db:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) over (2.1.27~101-g0780600+dfsg-3ubuntu2.1) ...
# Preparing to unpack .../12-libsasl2-2_2.1.27~101-g0780600+dfsg-3ubuntu2.3_amd64.deb ...
# Unpacking libsasl2-2:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) over (2.1.27~101-g0780600+dfsg-3ubuntu2.1) ...
# Preparing to unpack .../13-libldap-common_2.4.45+dfsg-1ubuntu1.10_all.deb ...
# Unpacking libldap-common (2.4.45+dfsg-1ubuntu1.10) over (2.4.45+dfsg-1ubuntu1.8) ...
# Preparing to unpack .../14-libldap-2.4-2_2.4.45+dfsg-1ubuntu1.10_amd64.deb ...
# Unpacking libldap-2.4-2:amd64 (2.4.45+dfsg-1ubuntu1.10) over (2.4.45+dfsg-1ubuntu1.8) ...
# Preparing to unpack .../15-libmysqlclient-dev_5.7.36-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking libmysqlclient-dev (5.7.36-0ubuntu0.18.04.1) over (5.7.35-0ubuntu0.18.04.2) ...
# Preparing to unpack .../16-libmysqlclient20_5.7.36-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking libmysqlclient20:amd64 (5.7.36-0ubuntu0.18.04.1) over (5.7.35-0ubuntu0.18.04.2) ...
# Preparing to unpack .../17-libxnvctrl0_495.29.05-0ubuntu1_amd64.deb ...
# Unpacking libxnvctrl0:amd64 (495.29.05-0ubuntu1) over (470.57.02-0ubuntu1) ...
# Preparing to unpack .../18-linux-libc-dev_4.15.0-161.169_amd64.deb ...
# Unpacking linux-libc-dev:amd64 (4.15.0-161.169) over (4.15.0-128.131) ...
# Preparing to unpack .../19-nvidia-settings_495.29.05-0ubuntu1_amd64.deb ...
# Unpacking nvidia-settings (495.29.05-0ubuntu1) over (470.57.02-0ubuntu1) ...
# Preparing to unpack .../20-r-cran-cpp11_0.4.0-1cran1.1804.0_all.deb ...
# Unpacking r-cran-cpp11 (0.4.0-1cran1.1804.0) over (0.3.1-1cran1.1804.0) ...
# Preparing to unpack .../21-r-cran-data.table_1.14.2-1cran1.1804.0_amd64.deb ...
# Unpacking r-cran-data.table (1.14.2-1cran1.1804.0) over (1.14.0-1cran1.1804.0) ...
# Preparing to unpack .../22-r-cran-desc_1.4.0-1cran1.1804.0_all.deb ...
# Unpacking r-cran-desc (1.4.0-1cran1.1804.0) over (1.3.0-1cran1.1804.0) ...
# Preparing to unpack .../23-r-cran-diffobj_0.3.5-1cran1.1804.0_amd64.deb ...
# Unpacking r-cran-diffobj (0.3.5-1cran1.1804.0) over (0.3.4-1cran1.1804.0) ...
# Preparing to unpack .../24-r-cran-digest_0.6.28-1cran1.1804.0_amd64.deb ...
# Unpacking r-cran-digest (0.6.28-1cran1.1804.0) over (0.6.27-1cran1.1804.0) ...
# Preparing to unpack .../25-r-cran-rlang_0.4.12-1cran1.1804.0_amd64.deb ...
# Unpacking r-cran-rlang (0.4.12-1cran1.1804.0) over (0.4.11-1cran1.1804.0) ...
# Preparing to unpack .../26-r-cran-lifecycle_1.0.1-1cran1.1804.0_all.deb ...
# Unpacking r-cran-lifecycle (1.0.1-1cran1.1804.0) over (1.0.0-1cran1.1804.0) ...
# Preparing to unpack .../27-r-cran-hms_1.1.1-1cran1.1804.0_all.deb ...
# Unpacking r-cran-hms (1.1.1-1cran1.1804.0) over (1.1.0-1cran1.1804.0) ...
# Preparing to unpack .../28-r-cran-xfun_0.27-1cran1.1804.0_amd64.deb ...
# Unpacking r-cran-xfun (0.27-1cran1.1804.0) over (0.26-1cran1.1804.0) ...
# Preparing to unpack .../29-r-cran-knitr_1.36-1cran1.1804.0_all.deb ...
# Unpacking r-cran-knitr (1.36-1cran1.1804.0) over (1.34-1cran1.1804.0) ...
# Preparing to unpack .../30-r-cran-lubridate_1.8.0-1cran1.1804.0_amd64.deb ...
# Unpacking r-cran-lubridate (1.8.0-1cran1.1804.0) over (1.7.10-1cran1.1804.0) ...
# Preparing to unpack .../31-r-cran-mgcv_1.8-38-1.1804.0_amd64.deb ...
# Unpacking r-cran-mgcv (1.8-38-1.1804.0) over (1.8-37-1.1804.0) ...
# Preparing to unpack .../32-r-cran-mime_0.12-1cran1.1804.0_amd64.deb ...
# Unpacking r-cran-mime (0.12-1cran1.1804.0) over (0.11-1cran1.1804.0) ...
# Preparing to unpack .../33-r-cran-pillar_1.6.4-1cran1.1804.0_all.deb ...
# Unpacking r-cran-pillar (1.6.4-1cran1.1804.0) over (1.6.2-1cran1.1804.0) ...
# Preparing to unpack .../34-r-cran-pkgload_1.2.3-1cran1.1804.0_all.deb ...
# Unpacking r-cran-pkgload (1.2.3-1cran1.1804.0) over (1.2.2-1cran1.1804.0) ...
# Preparing to unpack .../35-r-cran-rcmdcheck_1.4.0-1cran1.1804.0_all.deb ...
# Unpacking r-cran-rcmdcheck (1.4.0-1cran1.1804.0) over (1.3.3-1cran1.1804.0) ...
# Preparing to unpack .../36-r-cran-tibble_3.1.5-1cran1.1804.0_amd64.deb ...
# Unpacking r-cran-tibble (3.1.5-1cran1.1804.0) over (3.1.4-1cran1.1804.0) ...
# Preparing to unpack .../37-r-cran-readr_2.0.2-1cran1.1804.0_amd64.deb ...
# Unpacking r-cran-readr (2.0.2-1cran1.1804.0) over (2.0.1-1cran1.1804.0) ...
# Preparing to unpack .../38-r-cran-remotes_2.4.1-1cran1.1804.0_all.deb ...
# Unpacking r-cran-remotes (2.4.1-1cran1.1804.0) over (2.4.0-1cran1.1804.0) ...
# Preparing to unpack .../39-r-cran-rvest_1.0.2-1cran1.1804.0_all.deb ...
# Unpacking r-cran-rvest (1.0.2-1cran1.1804.0) over (1.0.1-1cran1.1804.0) ...
# Preparing to unpack .../40-r-cran-stringi_1.7.5-1cran1.1804.0_amd64.deb ...
# Unpacking r-cran-stringi (1.7.5-1cran1.1804.0) over (1.7.4-1cran1.1804.0) ...
# Preparing to unpack .../41-r-cran-systemfonts_1.0.3-1cran1.1804.0_amd64.deb ...
# Unpacking r-cran-systemfonts (1.0.3-1cran1.1804.0) over (1.0.2-1cran1.1804.0) ...
# Preparing to unpack .../42-r-cran-testthat_3.1.0-1cran1.1804.0_amd64.deb ...
# Unpacking r-cran-testthat (3.1.0-1cran1.1804.0) over (3.0.4-1cran1.1804.0) ...
# Preparing to unpack .../43-r-cran-tidyr_1.1.4-1cran1.1804.0_amd64.deb ...
# Unpacking r-cran-tidyr (1.1.4-1cran1.1804.0) over (1.1.3-1cran1.1804.0) ...
# Preparing to unpack .../44-r-cran-tinytex_0.34-1cran1.1804.0_all.deb ...
# Unpacking r-cran-tinytex (0.34-1cran1.1804.0) over (0.33-1cran1.1804.0) ...
# Preparing to unpack .../45-r-cran-usethis_2.1.0-1cran1.1804.0_all.deb ...
# Unpacking r-cran-usethis (2.1.0-1cran1.1804.0) over (2.0.1-1cran1.1804.0) ...
# Preparing to unpack .../46-gnupg2_2.2.4-1ubuntu1.4_all.deb ...
# Unpacking gnupg2 (2.2.4-1ubuntu1.4) over (2.2.4-1ubuntu1.3) ...
# Preparing to unpack .../47-nvidia-modprobe_495.29.05-0ubuntu1_amd64.deb ...
# Unpacking nvidia-modprobe (495.29.05-0ubuntu1) over (470.57.02-0ubuntu1) ...
# Setting up libcudnn7 (7.6.5.32-1+cuda10.2) ...
# Setting up r-cran-diffobj (0.3.5-1cran1.1804.0) ...
# Setting up libldap-common (2.4.45+dfsg-1ubuntu1.10) ...
# Setting up libsasl2-modules-db:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# Setting up r-cran-desc (1.4.0-1cran1.1804.0) ...
# Setting up linux-libc-dev:amd64 (4.15.0-161.169) ...
# Setting up libsasl2-2:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# Setting up libcudnn7-dev (7.6.5.32-1+cuda10.2) ...
# update-alternatives: using /usr/include/x86_64-linux-gnu/cudnn_v7.h to provide /usr/include/cudnn.h (libcudnn) in manual mode
# Setting up distro-info-data (0.37ubuntu0.13) ...
# Setting up r-cran-xfun (0.27-1cran1.1804.0) ...
# Setting up binutils-common:amd64 (2.30-21ubuntu1~18.04.7) ...
# Setting up gnupg2 (2.2.4-1ubuntu1.4) ...
# Setting up libcublas10 (10.2.3.254-1) ...
# Setting up libcublas-dev (10.2.3.254-1) ...
# Setting up r-cran-mgcv (1.8-38-1.1804.0) ...
# Setting up libldap-2.4-2:amd64 (2.4.45+dfsg-1ubuntu1.10) ...
# Setting up r-cran-stringi (1.7.5-1cran1.1804.0) ...
# Setting up r-cran-remotes (2.4.1-1cran1.1804.0) ...
# Setting up nvidia-modprobe (495.29.05-0ubuntu1) ...
# Setting up openssl (1.1.1-1ubuntu2.1~18.04.13) ...
# Setting up r-cran-cpp11 (0.4.0-1cran1.1804.0) ...
# Setting up libmysqlclient20:amd64 (5.7.36-0ubuntu0.18.04.1) ...
# Setting up libcaca0:amd64 (0.99.beta19-2ubuntu0.18.04.3) ...
# Setting up r-cran-mime (0.12-1cran1.1804.0) ...
# Setting up r-cran-rlang (0.4.12-1cran1.1804.0) ...
# Setting up r-cran-digest (0.6.28-1cran1.1804.0) ...
# Setting up libxnvctrl0:amd64 (495.29.05-0ubuntu1) ...
# Setting up r-cran-data.table (1.14.2-1cran1.1804.0) ...
# Setting up r-cran-tinytex (0.34-1cran1.1804.0) ...
# Setting up r-cran-pkgload (1.2.3-1cran1.1804.0) ...
# Setting up libmysqlclient-dev (5.7.36-0ubuntu0.18.04.1) ...
# Setting up libbinutils:amd64 (2.30-21ubuntu1~18.04.7) ...
# Setting up r-cran-rcmdcheck (1.4.0-1cran1.1804.0) ...
# Setting up r-cran-knitr (1.36-1cran1.1804.0) ...
# Setting up r-cran-systemfonts (1.0.3-1cran1.1804.0) ...
# Setting up nvidia-settings (495.29.05-0ubuntu1) ...
# Setting up r-cran-lubridate (1.8.0-1cran1.1804.0) ...
# Setting up r-cran-lifecycle (1.0.1-1cran1.1804.0) ...
# Setting up r-cran-hms (1.1.1-1cran1.1804.0) ...
# Setting up r-cran-usethis (2.1.0-1cran1.1804.0) ...
# Setting up r-cran-pillar (1.6.4-1cran1.1804.0) ...
# Setting up r-cran-testthat (3.1.0-1cran1.1804.0) ...
# Setting up binutils-x86-64-linux-gnu (2.30-21ubuntu1~18.04.7) ...
# Setting up r-cran-tibble (3.1.5-1cran1.1804.0) ...
# Setting up r-cran-tidyr (1.1.4-1cran1.1804.0) ...
# Setting up r-cran-readr (2.0.2-1cran1.1804.0) ...
# Setting up r-cran-rvest (1.0.2-1cran1.1804.0) ...
# Setting up binutils (2.30-21ubuntu1~18.04.7) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.4) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Calculating upgrade... Done
# The following packages were automatically installed and are no longer required:
#   linux-headers-4.15.0-159 linux-headers-4.15.0-159-generic
# Use 'sudo apt autoremove' to remove them.
# The following NEW packages will be installed:
#   linux-headers-4.15.0-161 linux-headers-4.15.0-161-generic nvidia-prime
# The following packages have been kept back:
#   cuda-drivers libcudnn8 libcudnn8-dev libnccl-dev libnccl2
# The following packages will be upgraded:
#   linux-headers-generic
# 1 upgraded, 3 newly installed, 0 to remove and 5 not upgraded.
# Need to get 12.2 MB of archives.
# After this operation, 90.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 linux-headers-4.15.0-161 all 4.15.0-161.169 [10.9 MB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 linux-headers-4.15.0-161-generic amd64 4.15.0-161.169 [1,252 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 linux-headers-generic amd64 4.15.0.161.150 [2,440 B]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 nvidia-prime all 0.8.16~0.18.04.1 [9,224 B]
# Fetched 12.2 MB in 0s (46.4 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 4.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package linux-headers-4.15.0-161.
# (Reading database ... 155067 files and directories currently installed.)
# Preparing to unpack .../linux-headers-4.15.0-161_4.15.0-161.169_all.deb ...
# Unpacking linux-headers-4.15.0-161 (4.15.0-161.169) ...
# Selecting previously unselected package linux-headers-4.15.0-161-generic.
# Preparing to unpack .../linux-headers-4.15.0-161-generic_4.15.0-161.169_amd64.deb ...
# Unpacking linux-headers-4.15.0-161-generic (4.15.0-161.169) ...
# Preparing to unpack .../linux-headers-generic_4.15.0.161.150_amd64.deb ...
# Unpacking linux-headers-generic (4.15.0.161.150) over (4.15.0.159.148) ...
# Selecting previously unselected package nvidia-prime.
# Preparing to unpack .../nvidia-prime_0.8.16~0.18.04.1_all.deb ...
# Unpacking nvidia-prime (0.8.16~0.18.04.1) ...
# Setting up nvidia-prime (0.8.16~0.18.04.1) ...
# Setting up linux-headers-4.15.0-161 (4.15.0-161.169) ...
# Setting up linux-headers-4.15.0-161-generic (4.15.0-161.169) ...
# /etc/kernel/header_postinst.d/dkms:
#  * dkms: running auto installation service for kernel 4.15.0-161-generic
#
# Kernel preparation unnecessary for this kernel.  Skipping...
# applying patch disable_fstack-clash-protection_fcf-protection.patch...patching file Kbuild
# Hunk #1 succeeded at 82 (offset 11 lines).
#
#
# Building module:
# cleaning build area...(bad exit status: 2)
# unset ARCH; [ ! -h /usr/bin/cc ] && export CC=/usr/bin/gcc; env NV_VERBOSE=1 'make' -j2 NV_EXCLUDE_BUILD_MODULES='' KERNEL_UNAME=4.15.0-161-generic IGNORE_XEN_PRESENCE=1 IGNORE_CC_MISMATCH=1 SYSSRC=/lib/modules/4.15.0-161-generic/build LD=/usr/bin/ld.bfd modules..........................
# cleaning build area...(bad exit status: 2)
#
# DKMS: build completed.
#
# nvidia.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-161-generic/updates/dkms/
#
# nvidia-modeset.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-161-generic/updates/dkms/
#
# nvidia-drm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-161-generic/updates/dkms/
#
# nvidia-uvm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-161-generic/updates/dkms/
#
# nvidia-peermem.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-161-generic/updates/dkms/
#
# depmod...
#
# DKMS: install completed.
#    ...done.
# Setting up linux-headers-generic (4.15.0.161.150) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages will be REMOVED:
#   linux-headers-4.15.0-159 linux-headers-4.15.0-159-generic
# 0 upgraded, 0 newly installed, 2 to remove and 5 not upgraded.
# After this operation, 90.0 MB disk space will be freed.
# (Reading database ... 184398 files and directories currently installed.)
# Removing linux-headers-4.15.0-159-generic (4.15.0-159.167) ...
# dpkg: warning: while removing linux-headers-4.15.0-159-generic, directory '/lib/modules/4.15.0-159-generic' not empty so not removed
# Removing linux-headers-4.15.0-159 (4.15.0-159.167) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libopenblas-dev is already the newest version (0.2.20+ds-4).
# 0 upgraded, 0 newly installed, 0 to remove and 5 not upgraded.

# %%
# %%shell
#
# sudo apt-get update && sudo apt-get install libboost-all-dev
# sudo apt-get -y install --fix-missing libboost-all-dev
# sudo apt-get install libfaac-dev
# sudo apt-get -y remove ffmpeg x264 libx264-dev
# sudo add-apt-repository ppa:mc3man/trusty-media
# sudo apt-get update && sudo apt-get install ffmpeg gstreamer0.10-ffmpeg
# Out:
# Hit:1 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:4 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:5 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:6 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:7 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:8 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Ign:9 http://archive.ubuntu.com/ubuntu trusty InRelease
# Get:10 http://archive.ubuntu.com/ubuntu trusty Release [58.5 kB]
# Get:11 http://archive.ubuntu.com/ubuntu trusty Release.gpg [933 B]
# Hit:12 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Ign:13 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:14 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:15 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:16 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:17 http://archive.ubuntu.com/ubuntu trusty/main amd64 Packages [1,743 kB]
# Get:18 http://archive.ubuntu.com/ubuntu trusty/multiverse amd64 Packages [169 kB]
# Get:19 http://archive.ubuntu.com/ubuntu trusty/restricted amd64 Packages [16.0 kB]
# Get:20 http://archive.ubuntu.com/ubuntu trusty/universe amd64 Packages [7,589 kB]
# Fetched 9,740 kB in 1s (6,671 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libboost-all-dev is already the newest version (1.65.1.0ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 5 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libboost-all-dev is already the newest version (1.65.1.0ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 5 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libfaac0
# The following NEW packages will be installed:
#   libfaac-dev libfaac0
# 0 upgraded, 2 newly installed, 0 to remove and 5 not upgraded.
# Need to get 90.8 kB of archives.
# After this operation, 379 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libfaac0 amd64 1.29.7.7-1 [44.4 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libfaac-dev amd64 1.29.7.7-1 [46.5 kB]
# Fetched 90.8 kB in 0s (1,132 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 2.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libfaac0:amd64.
# (Reading database ... 155084 files and directories currently installed.)
# Preparing to unpack .../libfaac0_1.29.7.7-1_amd64.deb ...
# Unpacking libfaac0:amd64 (1.29.7.7-1) ...
# Selecting previously unselected package libfaac-dev:amd64.
# Preparing to unpack .../libfaac-dev_1.29.7.7-1_amd64.deb ...
# Unpacking libfaac-dev:amd64 (1.29.7.7-1) ...
# Setting up libfaac0:amd64 (1.29.7.7-1) ...
# Setting up libfaac-dev:amd64 (1.29.7.7-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.4) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Package 'libx264-dev' is not installed, so not removed
# Package 'x264' is not installed, so not removed
# The following packages will be REMOVED:
#   ffmpeg
# 0 upgraded, 0 newly installed, 1 to remove and 5 not upgraded.
# After this operation, 2,276 kB disk space will be freed.
# (Reading database ... 155100 files and directories currently installed.)
# Removing ffmpeg (7:3.4.8-0ubuntu0.2) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
#  Upgraded, advanced or not normally available multimedia packages for Trusty
# Xenial users go here - https://launchpad.net/~mc3man/+archive/ubuntu/xerus-media
#
# *Please note that if using this ppa I would *not* try upgrading to 14.10/15.04, ect. Do a fresh install instead. The intent here is just for users wishing to stay on 14.04*
#
# If upgrading releases anyway use ppa-purge *First* -
# sudo ppa-purge  ppa:mc3man/trusty-media
#
# Also note that using this ppa then disabling may cause issue for installing i386 packages like used by wine. So once enabled leave enabled or purge before removing.
#
# Additionally if using apt-get * sudo  apt-get dist-upgrade will be needed* at times.(pay attention).  Otherwise package managers may be ok.
#
# So typically to enable & first use -
# sudo add-apt-repository ppa:mc3man/trusty-media
# sudo apt-get update
# sudo apt-get dist-upgrade
#
# A few notes:
# gstreamer0.10-ffmpeg - needed for some apps that still use gstreamer-0.10 & also provides h.264 in html5 decoding for firefox < 30.
# Note that Firefox 30 will support h.264 in html5 thru gstreamer1.0-libav & should be available soon
#
# A standalone ppa is here for gstreamer0.10-ffmpeg  -
# https://launchpad.net/~mc3man/+archive/ubuntu/gstffmpeg-keep
#
# Vlc: after upgrading please remove ~/.config/vlc folder to ensure proper runnning
#
# Totem - New - have added a --no-existing-session option to open a 2nd instance. Unity users can also find it in the totem quicklist
#
# Totem+grilo - it's quite possible this & RB+grilo will show in 14.04 by first point release, if so will probably remove. Also note some plugins work well, some don't at all, bit of a mess. Note that the youtube plugin is again broken, I'll not fix.
#
# rhythmbox+grilo - needs to be enabled in rhythmbox > tools > plugins
# Plus install grilo-plugins if not already
#
# mpv - has been removed as 14.04.4-lts requires higher libva than what's in 14.04 or in this ppa
# Available here with newer libva & i965 driver
# https://launchpad.net/~mc3man/+archive/mpv-tests
#
# mplayer - described here, note mencoder is not inc. & likely will not be, you may be able to use repo mencoder..
# https://launchpad.net/~mc3man/+archive/mplayer-test
#
# fdkaac (fdkaac-encoder) - described here
# https://launchpad.net/~mc3man/+archive/fdkaac-encoder
#
# x264 - for use with ffmpeg from here, supports both 8 & 10 bit encoding
#
# ffmpeg -
# a static build for use of the binaries, installed to /opt/ffmpeg
# binaries are symlinked in /usr/bin (ffmpeg, ffplay, ffprobe
# ffmpeg has nvenc enabled, ymmv depending on hardware/source files, ect.
# See for encoder names -
#  ffmpeg -encoders 2>/dev/null | grep nvenc
#
# For info on using libfdk_aac see here -
# http://trac.ffmpeg.org/wiki/Encode/AAC
#
# Can be used for both 8 & 10 bit x264 encoding with this ppa's libx264, default is 8
# For 10 bit preload the 10 bit .so first in terminal, eg.,
# export LD_PRELOAD=/usr/lib/x86_64-linux-gnu/x264-10bit/libx264.so.142
# or
# export LD_PRELOAD=/usr/lib/i386-linux-gnu/x264-10bit/libx264.so.142
#
# libav - has fdkaac encoding enabled
#
# yasm -
#  has been patched to improve compiling x265
#
# devede -
#  can use either avconv or ffmpeg from here
#  1st choice for previewer is mplayer (version here is best
#
# K9copy -
# Mainly for ripping, as far as encoding there are better apps. If inclined to use for encoding then use mencoder as ffmpeg support is quite limited
#
# For rhythmbox users a wide range of plugins can be found here -
# https://launchpad.net/~fossfreedom/+archive/rhythmbox-plugins
#
# Abcde -
# ck. Suggested in synaptic for add. useful packages
# A guide to config is here -
# http://www.andrews-corner.org/abcde.html
#
# An excellent  audio recorder is available here -
# https://launchpad.net/~osmoma/+archive/audio-recorder
#
# A good blender ppa is here -
#  https://launchpad.net/~irie/+archive/blender
#
# To further extend this ppa to libav11 check here -
# https://launchpad.net/~mc3man/+archive/ubuntu/testing6
#
# To repeat -
# *Please note that if using this ppa I would *not* try upgrading to 14.10/15.04, ect. Do a fresh install instead. The intent here is just for users wishing to stay on 14.04*
# If upgrading anyway use ppa-purge first -
# sudo ppa-purge  ppa:mc3man/trusty-media
#
# Also note that with apt-get a sudo apt-get dist-upgrade is needed for initial setup & with some package upgrades
#  More info: https://launchpad.net/~mc3man/+archive/ubuntu/trusty-media
# Press [ENTER] to continue or Ctrl-c to cancel adding it.

# %%
# %%shell
# sudo apt-get install build-essential
# sudo apt-get install cmake git libgtk2.0-dev pkg-config libavcodec-dev libavformat-dev libswscale-dev
# sudo apt-get install python-dev python-numpy libtbb2 libtbb-dev libjpeg-dev libpng-dev libtiff-dev libjasper-dev libdc1394-22-dev
# sudo apt-get install libtiff4-dev libopenexr-dev libeigen2-dev yasm libopencore-amrnb-dev libtheora-dev libvorbis-dev libxvidcore-dev
# sudo apt-get install python-tk libeigen3-dev libx264-dev libqt4-dev libqt4-opengl-dev sphinx-common texlive-latex-extra libv4l-dev default-jdk ant libvtk5-qt4-dev

# %%
# %%shell
# cd ~
# wget http://sourceforge.net/projects/opencvlibrary/files/opencv-unix/2.4.9/opencv-2.4.9.zip
# unzip opencv-2.4.9.zip
# cd opencv-2.4.9
# mkdir build
# cd build
# cmake -D WITH_TBB=ON -D BUILD_NEW_PYTHON_SUPPORT=ON -D WITH_V4L=ON -D INSTALL_C_EXAMPLES=ON -D INSTALL_PYTHON_EXAMPLES=ON -D BUILD_EXAMPLES=ON -D WITH_QT=ON -D WITH_OPENGL=ON -D WITH_VTK=ON ..
# sudo make -j4
# sudo make install

# %%
# %%shell
# sudo sh -c 'echo "/usr/local/lib" > /etc/ld.so.conf.d/opencv.conf'
# sudo ldconfig
# export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/usr/local/opencv/lib
#
# cd ~
# sudo apt-get install python-pip
# sudo apt-get install python-numpy python-scipy python-matplotlib ipython ipython-notebook python-pandas python-sympy python-nose

# %%
# %%shell
# wget http://cython.org/release/Cython-0.23.4.zip
# unzip Cython-0.23.4.zip
# cd Cython-0.23.4
# sudo python setup.py install
# cd ~
#
# sudo pip install scikit-image scikit-learn
#
# sudo apt-get install libprotobuf-dev libleveldb-dev libsnappy-dev libopencv-dev libhdf5-serial-dev
# sudo apt-get install libgflags-dev libgoogle-glog-dev liblmdb-dev protobuf-compiler
# sudo pip install protobuf

# %%
# %%shell
#
# sudo apt-get install python-pydot
# git clone https://github.com/BVLC/caffe
# cd caffe
# cp Makefile.config.example Makefile.config
